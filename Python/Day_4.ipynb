# %% [markdown]
# # **Session 6: FRONTIER TECH LEADERS PROGRAMME PYTHON SPECIALIZATION BOOT CAMP CRASH COURSE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **OBJECT ORIENTED PROGRAMMING**

# %% [markdown]
# ## Learning Objectives
#
# * To have a fundamental understanding of the concept of object oriented programming
#
# * To understand the structure of Object oriented programming in Python
#
# * To understand the key concepts of Python object oriented programming.
#
#
#
# ## Learning Outcomes
# Demonstrate the ability:
#
# * To comfortably invoke methods of Python Built in class.
# * To create custom Python classes and objects, and call methods.

# %% [markdown]
# # **OBJECT ORIENTED PROGRAMMING**

# %% [markdown]
# > Python is an object-oriented programming language
#
# **What does it mean?**
#
# Object-Oriented Programming (OOP) is a programming paradigm that focuses on the use of objects and classes to create programs.
#
# > An object is a group of interrelated variables and functions.
# > Vvariables are often referred to as ***properties (attributes)*** of the object
# > Functions (methods) are referred to as the behavior of the objects.
#
#
# **Why Use Object-Oriented Programming?**
#
# * OPP makes code more reusable and easier to work with larger programs.
# * OOP programs prevent you from repeating code because a class can be defined once and reused many times.

# %% [markdown]
#  * A program is made up of one or more objects working together - Objects make use of each other's capabilities

# %% [markdown]
# # TERMINOLOGIES IN OBJECT ORIENTED PYTHON PROGRAMMING
#
# > In Python, classes are the primary tool for implementing Object-Oriented Programming (OOP) principles.
#
# In OOP, there are several key terminologies that form the backbone of the paradigm:
#
# 1. Class - A template
#
# 2. Attribute - A variable within a class
#
# 3. Method - A function within a class
#
# 4. Object - A particular instance of a class
#
# 5. Constructor - Code that runs when an object is created
#
# 6. Inheritance - The ability to extend a class to make a new class
#
# Others include:
#
#
# 8. Polymorphism
# 9. Data Abstraction
# 10. Encapsulation

# %% [markdown]
# ## **1. Classes**
#
# Classes define the properties (attributes) and behaviors (methods) of the object.
#
# > Think of a class as a blueprint for creating objects. The
#
#
#
# **For instance:** A class Dog would consist of traits shared by all dogs, such as breed and fur color (characteristics), and the ability to bark and sit(behaviours)

# %% [markdown]
# ## **2. Instance**
#
# An instance of a class is an object. It is also known as a class object or class instance.
#
# It is the actual object created at runtime.
#
# An object can contain data and code to manipulate that data
#
# For example: Golden Retriever object is an instance of the Dog class.

# %% [markdown]
# ## 3. Method
#
# Methods are the functions we use to describe the behavior of objects.
#
# They are  defined inside a class.
#
# >A method is a procedure associated with an object, and generally also a message. An object consists of state data and behavior; these compose an interface, which specifies how the object may be used. A method is a behavior of an object parametrized by a user [source](https://en.wikipedia.org/wiki/Method_(computer_programming)).
#
# In language, methods are verbs.
#
#
# Golden Retriever, as a Dog, has the ability to bark. Meaning bark() is one of Golden Retriever's methods. It could also sit(), run(), eat(), etc.
#
# Note: Using a method in your program affects only one particular object. E.g All dogs can bark. But you need only one dog to do the barking.

# %% [markdown]
# **Some Principles of Object Oriented Programming**
#
# The principles of OOP include: encapsulation, inheritance, polymorphism, and abstraction.
#
# Note: No worries about these for now. Not part of the course.

# %% [markdown]
# ## Python Pre-Built Objects

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Comments:**
#
# When we assign a value to a variable, we are creating an object. This object belongs to a particular class already pre-built, like numbers, strings, lists, dictionaries and so on. Depending on the class, the object will have different properties and methods.

# %%
a = 28 # a is an object or instance of the integer class

print(type(a))
# Out:
# <class 'int'>

# %%
l = [1,2,3]

print(type(l))
# Out:
# <class 'list'>

# %%
st = 'Hello'

print(type(st))
# Out:
# <class 'str'>

# %% [markdown]
# To see all the methods allowed in the object, we use the `dir() function`

# %%
dir(l)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# **Comment on Output**
#
# Class provides three method types:
#
# * **Initializer method (Constructor):** `__init__` method that initializes the **attributes** of the object.
#  * Automatically called once the object is created.
#  * Known as constructor of the class.
#
# * **Magical methods**: Special methods with double underscores on both sides.
#  * For example, __add__ and __mul__ are used to respectively sum and multiplicate objects of the same class.
#
# * **Instance methods**: Methods that belong to the object created.
#   * For example, l.append(4) adds an element at the end of the list.

# %% [markdown]
# ## 1.**How to Build Your First Class and Object**
#
# Before we built our first class in Python, know that someone had to follow these steps you are about to learn to create the built-in classes you know enjoy e.g list(), dict(), str() etc.
#
# **Good News:**
# * You won't be writing lots of classes. Goal is to understand how classes work from the inside out.

# %% [markdown]
# **Remember**:
# Every class contains data and code to manipulate that data.

# %% [markdown]
# ## **Building a Dog Class in Python**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now, we'll learn how to create a class in Python by building a simple `Dog` class from scratch.
#
# **Objective:** Understand how classes can be structured and used.
#
#
#
# ### Steps
# * Creating an Empty Dog Class
# * Adding Attributes
# * Adding Methods
# * Introducing Class Attributes
# * Inheritance

# %% [markdown]
# **Step 1: Creating an Empty Dog Class**

# %%
# Step 1: Create an empty Dog class

#class definition of the Dog Class
class Dog:
  pass

#create a dog object
dog1 = Dog()


print(type(dog1))
# Out:
# <class '__main__.Dog'>

# %% [markdown]
# **Comments:**
#
# We've just created our first class named `Dog`.
# The `pass` keyword means "do nothing" and it's just a placeholder since Python doesn't allow empty class bodies. When we created an instance of the `Dog` class and printed its type, Python confirmed that it's an instance of our `Dog` class.

# %% [markdown]
# **Step 2: Adding instance attribute**
#
# Attributes are variables that store data for an instance of a class.

# %%
# Step 2: Adding attributes
class Dog:

  def __init__(self, givenName, givenAge):
    self.name = givenName
    self.age = givenAge




#def __init__()
#self
buddy = Dog('Buddy', 4) #object of class Dog (real dog)
husky = Dog('Husky', 2)
papi = Dog('Papi', 3)

print(f" Dog Name is {buddy.name} and Age is {buddy.age}")
print(f" Dog Name is {husky.name} and Age is {husky.age}")
print(f" Dog Name is {papi.name} and Age is {papi.age}")
# Out:
#  Dog Name is Buddy and Age is 4
#  Dog Name is Husky and Age is 2
#  Dog Name is Papi and Age is 3

# %% [markdown]
# **Comment:**
#
# * `__init__` method to initialize the attributes when a new instance of a class is created.
#
# * `Self` variable is used to represent the instance of the class.

# %% [markdown]
# **Note:**
# * Instance variables belong to each individual object (or 'instance') of a class.
# e.g one Dog object might have the name "Husky", while another might be named "Bulldog".
# * Instance variables are defined within methods

# %% [markdown]
#  **Step 3: Adding methods**

# %% [markdown]
# Methods are functions that are defined inside a class and can access and modify class data.

# %%
# Step 3: Adding methods
# Step 2: Adding attributes
class Dog:

  def __init__(self, givenName, givenAge , istired):
    self.name = givenName
    self.age = givenAge
    self.tired = istired

  def eat(self , var):

    return f"{self.name} is eating loudly!"


  def sleep(self):

    if self.tired == True:

      return f"{self.name} wants to sleep!"

    else:
      return f"{self.name} wants to play"

# %%
dog1 = Dog('Hidi' , 3 , True)

dog1.sleep()
# Out:
# 'Hidi wants to sleep!'

# %%
dog2 = Dog('Yupa', 7, False )

# %%
dog2.tired
# Out:
# False

# %%
dog2.sleep()
# Out:
# 'Yupa wants to play'

# %%
dog1.sleep()
# Out:
# 'Hidi wants to sleep!'

# %%
dog2.name
# Out:
# 'Yupa'

# %%
dog2.age
# Out:
# 7

# %%
dog1.name
# Out:
# 'Hidi'

# %% [markdown]
# **Comments**:
# We've added our first method, `bark()`, to the `Dog` class.
#
#
# In our example, the `bark()` method returns a string indicating that the dog is barking. Note how we use `self.name` to access the name attribute of the current instance within the method.

# %% [markdown]
# **Step 4: Introducing class attributes**
#
# Class attributes refer to the attributes outside the constructor method.
# They are shared by all instances of a class. They're useful for storing constants or default values.

# %%
#step 4: introduce class attribute


#instance attribute and Class attribute
class Dog:

  species = 'Canine' #class attribute

  def __init__(self, givenName, givenAge , istired):
    self.name = givenName
    self.age = givenAge
    self.tired = istired #instance

  def eat(self , var):

    return f"{self.name} is eating loudly!"


  def sleep(self):

    if self.tired == True:

      return f"{self.name} wants to sleep!"

    else:
      return f"{self.name} wants to play"

# %%
dog1 = Dog('Yupa', 7, False)

dog2 = Dog('Gunna', 2, True)

# %%
dog1.name
# Out:
# 'Yupa'

# %% [markdown]
# **Note:** In our `Dog` class, we'll introduce a class attribute named `species` that will be the same for all dogs.

# %%
dog2.name
# Out:
# 'Gunna'

# %%
dog1.name
# Out:
# 'Yupa'

# %%
dog1.species
# Out:
# 'Canine'

# %%
dog2.species
# Out:
# 'Canine'

# %%
#Overwriting Class (Not recommended) and Instance Variables

# %% [markdown]
# ## Inheritance
#
# Inheritance is a fundamental concept in object-oriented programming where a new class inherits attributes and behaviors (methods) from an existing class.
#
# * This allows for reusability of code and establishing relationships between the parent (base) class and the child (derived) class.
#
# * The new class is often called the **"child"** or **"subclass"**, while the class it inherits from is called the "parent" or "base class".

# %% [markdown]
# **Key Benefits:**
#
# * **Reusability:** You don't need to write the same code again; the child class inherits all the members of the parent class.
# * **Extensibility:** You can add more features to a child class beyond what it inherits.
# * **Hierarchy:** Establishes a form of hierarchy wherein all related classes share a common base.

# %% [markdown]
# ### **Extending the Dog Class Example:**

# %%
# Base Class

#step 4: introduce class attribute

#Parent
#instance attribute and Class attribute
class Dog:

  species = 'Canine' #class attribute

  def __init__(self, givenName, givenAge , istired):
    self.name = givenName
    self.age = givenAge
    self.tired = istired #instance

  def eat(self):

    return f"{self.name} is eating loudly!"


  def sleep(self):

    if self.tired == True:

      return f"{self.name} wants to sleep!"

    else:
      return f"{self.name} wants to play"

#child class
class GoldenRetriever(Dog):

  breed = "Golden Retriever"


  def fetch(self , item):

    return f"{self.name} fetched the {item}"


rex = GoldenRetriever("Rex" , 4 , True)

print(rex.eat())
print(rex.sleep())

print(rex.fetch('Ball'))
# Out:
# Rex is eating loudly!
# Rex wants to sleep!
# Rex fetched the Ball

# %% [markdown]
# **Comment**:
# * The `GoldenRetriever` class inherits from the Dog class. This means all attributes and methods of the Dog class are available to the GoldenRetriever class.
# * We added a new attribute `breed` and a new method `fetch()` specifically for the `GoldenRetriever` class.
# * Notice how the `GoldenRetriever` class didn't have to redefine the `bark()` method or the species attribute. They were inherited directly from the `Dog` class.

# %% [markdown]
# ## **Encapsulation**:
# Encapsulation is about bundling data (attributes) and methods inside a class and restricting access to some of its components. In Python, prefixing attributes with _ or __ signals that they are for internal use.

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance  # Private attribute

    def deposit(self, amount):
        self.__balance += amount
    
    def get_balance(self):  # Public method to access private attribute
        return self.__balance

# %% [markdown]
# ## **Abstraction**
#
# Abstraction hides complex details and exposes only the necessary parts. Python’s abc module helps create abstract base classes (ABCs) with abstract methods.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

# Usage
rect = Rectangle(5, 10)
print("Area of rectangle:", rect.area())

# %% [markdown]
# ## **Polymorphism**
#
# Polymorphism lets different objects be used interchangeably through a common interface. It means that methods with the same name can behave differently on different classes.

# %%
class Animal:
    def speak(self):
        pass

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"

animals = [Dog(), Cat()]

for animal in animals:
    print(animal.speak())  # Outputs "Woof!" then "Meow!"

# %% [markdown]
# **Protected Attributes and Methods**:
#
# In Python, a single underscore (e.g., _age) denotes a protected attribute or method.

# %%
class Person:
    def __init__(self):
        self._age = 18

# %% [markdown]
# **Private Attributes and Methods**:
#
# A double underscore (e.g., __age) denotes a private attribute or method. This will cause the attribute name to be "mangled" by the interpreter, making it harder to access from outside the class.

# %%
class Person:
    def __init__(self):
        self.__age = 18

# %% [markdown]
# ## **Project: Refactor the Shape Class to Use Private Variables and Accessor Methods**

# %%
import turtle

# Define a base Shape class
class Shape:
    # The constructor takes three arguments
    def __init__(self, turtle, sides, length):
        self.__t = turtle         # turtle instance
        self.__sides = sides
        self.__length = length
        
    def draw(self):
        for _ in range(self.__sides):
            self.__t.forward(self.__length)
            self.__t.right(360 / self.__sides)
    
    def get_sides(self):
        return self.__sides
    
    def get_length(self):
        return self.__length

# Define a Square class that extends Shape
class Square(Shape):
    # The constructor takes two arguments
    def __init__(self, turtle, length):
        super().__init__(turtle, 4, length)

# Define a Triangle class that extends Shape        
class Triangle(Shape):
    # The constructor takes two arguments
    def __init__(self, turtle, length):
        super().__init__(turtle, 3, length)

# Define a function that a list of shapes next to each other       
def draw_shapes(t, shapes):
    for shape in shapes:
        shape.draw()
        t.penup()
        t.forward(shape.get_length() * 2)  # Move to the next position
        t.pendown()

# Create a new turtle screen and set its background color
screen = turtle.Screen()
screen.setup(width=800, height=600)
screen.bgcolor("white")

# Initialize a turtle object
t = turtle.Turtle()

# Create Shape objects
shapes = [Square(t, 50), Triangle(t, 50), Square(t, 100)]

# Draw the shapes
draw_shapes(t, shapes)

# Hide the turtle and wait until the window is closed
t.hideturtle()
turtle.done()

# %%
def my_decorator(func):
    def wrapper():
        print("Before invoke function")
        func()
        print("After invoke function")
    return wrapper

@my_decorator
def say_smt():
    print("say smth")
    
say_smt()
# Out:
# Before invoke function
# say smth
# After invoke function

# %% [markdown]
# **References**
#
# * https://github.com/drvinceknight/oop/blob/master/nbs/main.ipynb
#
# * https://towardsdatascience.com/explaining-python-classes-in-a-simple-way-e3742827c8b5
# * https://www.analyticsvidhya.com/blog/2020/09/object-oriented-programming/
